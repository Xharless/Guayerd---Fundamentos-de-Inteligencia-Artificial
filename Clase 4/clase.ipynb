# %% [markdown]
# # Introducción IA
# * **Explorar**: ¿Que patrones existe?
# * **Comparar**: ¿En qué se diferencian?
# * **Explicar**: ¿Por que sucede esto?
# * **Anticipar**: ¿Que ocurrirá despues?
#
# # Estructurar cualquier analisis
#
# ### Problema
# * Que [accion/resultado] queremos lograr
# * Por qué [este problema] es prioritario
# ### Datos
# * Que [información] tenemos disponibles
# * Como [organizar/limpiar] para analizarla
# ### Enfoque
# * Qué [relaciones/patrones] explorar primero
# * Qué [variables] incluir o descartar
#
#
# # Aplicación en Machine Learning
# ### Ejemplo
# * ¿Predecir que clientes abandonaran con +85% precision?
# ### Preguntas de validación
# * ¿Los datos representan el problema real?
# * ¿El modelo mejora la decision actual?

# %% [markdown]
# # Condicionales

# %%
edad = 20
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres mayor de edad
